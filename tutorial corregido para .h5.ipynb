# %% [markdown]
# # Needed Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# import astropy
# import scipy
# import sklearn
import pandas as pd
import h5py

# %% [markdown]
# # Some basic python code

# %% [markdown]
# # Let's open some simu

# %%
# Tambien se puede usar codigo bash poniendo un ! antes
# !pwd # Para ver donde estamos parados
# Out:
# /home/acastello

# %%
# !dir /home/acastello/halos_list_con_headers.h5
# Out:
# /home/acastello/halos_list_con_headers.h5

# %%
data = h5py.File(r'/home/acastello/halos_list_con_headers.h5', 'r')

# %%
type(data)
# Out:
# h5py._hl.files.File

# %%
data.keys()

print("Claves del archivo HDF5:", list(data.keys()))
# Out:
# Claves del archivo HDF5: ['datos']

# %%
data['datos'].attrs.keys()

headers = data['datos'].attrs.get('headers', 'No se encontró el atributo headers')
print(headers)
# Out:
# ['ID' 'DescID' 'Mvir' 'Vmax' 'Vrms' 'Rvir' 'Rs' 'Np' 'X' 'Y' 'Z' 'VX' 'VY'
#  'VZ' 'JX' 'JY' 'JZ' 'Spin' 'rs_klypin' 'Mvir_all' 'M200b' 'M200c' 'M500b'
#  'M500c' 'Xoff' 'Voff' 'spin_bullock' 'b_to_a' 'c_to_a' 'A[x]' 'A[y]'
#  'A[z]' 'b_to_a(500b)' 'c_to_a(500b)' 'A[x](500b)' 'A[y](500b)'
#  'A[z](500b)' 'T/|U|' 'M_pe_Behroozi' 'M_pe_Diemer' 'Halfmass_Radius']

# %%
data['datos'].attrs.get('headers')
# Out:
# array(['ID', 'DescID', 'Mvir', 'Vmax', 'Vrms', 'Rvir', 'Rs', 'Np', 'X',
#        'Y', 'Z', 'VX', 'VY', 'VZ', 'JX', 'JY', 'JZ', 'Spin', 'rs_klypin',
#        'Mvir_all', 'M200b', 'M200c', 'M500b', 'M500c', 'Xoff', 'Voff',
#        'spin_bullock', 'b_to_a', 'c_to_a', 'A[x]', 'A[y]', 'A[z]',
#        'b_to_a(500b)', 'c_to_a(500b)', 'A[x](500b)', 'A[y](500b)',
#        'A[z](500b)', 'T/|U|', 'M_pe_Behroozi', 'M_pe_Diemer',
#        'Halfmass_Radius'], dtype=object)

# %%
# Renombrar las columnas de df con los headers obtenidos
headers = data['datos'].attrs.get('headers')  # Obtener los headers

archivo_dat = '/home/acastello/halos_list.dat'  # La ruta del archivo
df = pd.read_csv(archivo_dat, comment='#', delimiter=r'\s+', header=None)

# Verificar que el número de headers coincide con las columnas de df
if len(df.columns) == len(headers):
    df.columns = headers  # Asignar los headers al DataFrame
    print("Encabezados asignados correctamente.")
else:
    print(f"Error: El número de columnas en el DataFrame ({len(df.columns)}) no coincide con el número de encabezados ({len(headers)}).")

print(df.head())  # Para ver las primeras filas con los nuevos encabezados
# Out:
# Encabezados asignados correctamente.
#        ID  DescID          Mvir    Vmax    Vrms     Rvir      Rs   Np  \
# 0  102373      -1  6.202100e+11  124.88  108.57  174.076  58.927   32
# 1  102374      -1  4.574000e+12  269.56  244.08  338.839  48.953  119
# 2  102375      -1  1.628000e+12  242.84  198.63  240.131  12.480   26
# 3  102376      -1  1.317900e+12  212.80  180.01  223.799  14.595   38
# 4  102377      -1  8.527800e+11  159.03  134.75  193.571  23.626   14
#
#            X          Y  ...      A[z]  b_to_a(500b)  c_to_a(500b)  \
# 0  184.08424  202.29651  ...  71.71382       0.00000       0.00000
# 1  185.76231  203.21434  ... -12.13828       0.44362       0.28230
# 2  186.53806  203.56975  ...   2.04779       0.74768       0.35702
# 3  184.34959  201.53200  ...  33.89271       0.88800       0.40712
# 4  185.14621  202.58162  ... -22.41387       0.79248       0.31109
#
#    A[x](500b)  A[y](500b)  A[z](500b)   T/|U|  M_pe_Behroozi   M_pe_Diemer  \
# 0     0.00000     0.00000     0.00000  0.8473   8.445000e+11  7.753000e+11
# 1    47.67883   -30.40652    -9.83577  0.5456   4.929000e+12  2.713000e+12
# 2    46.17031    10.40742     1.61027  0.5651   2.806000e+12  3.876000e+11
# 3     8.58208     0.65469    33.83329  0.5659   1.944000e+12  4.652000e+11
# 4    33.60241     2.92901   -22.36425  0.6269   1.024000e+12  4.652000e+11
#
#    Halfmass_Radius
# 0          145.090
# 1          148.819
# 2           72.221
# 3           66.272
# 4           87.814
#
# [5 rows x 41 columns]

# %%
numpy_arrays = {}  # Un diccionario para almacenar los numpy arrays
for column in df.columns:
        numpy_arrays[column] = np.array(df[column])  # Convertir cada columna a un numpy array
        print(f"Columna '{column}' convertida a numpy array.")
    
    # Verificación: Imprimir los arrays convertidos
for column, arr in numpy_arrays.items():
        print(f"Array para la columna '{column}':")
        print(arr)

else:
    print(f"Error: El número de columnas en el DataFrame ({len(df.columns)}) no coincide con el número de encabezados ({len(headers)}).")

# Verificación: Imprimir el tipo de los arrays convertidos
for column, arr in numpy_arrays.items():
    print(f"Tipo de datos para la columna '{column}': {type(arr)}")
# Out:
# Columna 'ID' convertida a numpy array.
# Columna 'DescID' convertida a numpy array.
# Columna 'Mvir' convertida a numpy array.
# Columna 'Vmax' convertida a numpy array.
# Columna 'Vrms' convertida a numpy array.
# Columna 'Rvir' convertida a numpy array.
# Columna 'Rs' convertida a numpy array.
# Columna 'Np' convertida a numpy array.
# Columna 'X' convertida a numpy array.
# Columna 'Y' convertida a numpy array.
# Columna 'Z' convertida a numpy array.
# Columna 'VX' convertida a numpy array.
# Columna 'VY' convertida a numpy array.
# Columna 'VZ' convertida a numpy array.
# Columna 'JX' convertida a numpy array.
# Columna 'JY' convertida a numpy array.
# Columna 'JZ' convertida a numpy array.
# Columna 'Spin' convertida a numpy array.
# Columna 'rs_klypin' convertida a numpy array.
# Columna 'Mvir_all' convertida a numpy array.
# Columna 'M200b' convertida a numpy array.
# Columna 'M200c' convertida a numpy array.
# Columna 'M500b' convertida a numpy array.
# Columna 'M500c' convertida a numpy array.
# Columna 'Xoff' convertida a numpy array.
# Columna 'Voff' convertida a numpy array.
# Columna 'spin_bullock' convertida a numpy array.
# Columna 'b_to_a' convertida a numpy array.
# Columna 'c_to_a' convertida a numpy array.
# Columna 'A[x]' convertida a numpy array.
# Columna 'A[y]' convertida a numpy array.
# Columna 'A[z]' convertida a numpy array.
# Columna 'b_to_a(500b)' convertida a numpy array.
# Columna 'c_to_a(500b)' convertida a numpy array.
# Columna 'A[x](500b)' convertida a numpy array.
# Columna 'A[y](500b)' convertida a numpy array.
# Columna 'A[z](500b)' convertida a numpy array.
# Columna 'T/|U|' convertida a numpy array.
# Columna 'M_pe_Behroozi' convertida a numpy array.
# Columna 'M_pe_Diemer' convertida a numpy array.
# Columna 'Halfmass_Radius' convertida a numpy array.
# Array para la columna 'ID':
# [102373 102374 102375 ... 817640 817641 817642]
# Array para la columna 'DescID':
# [-1 -1 -1 ... -1 -1 -1]
# Array para la columna 'Mvir':
# [6.2021e+11 4.5740e+12 1.6280e+12 ... 1.5505e+11 4.6515e+11 3.1010e+11]
# Array para la columna 'Vmax':
# [124.88 269.56 242.84 ...  94.3  120.64  98.55]
# Array para la columna 'Vrms':
# [108.57 244.08 198.63 ...   0.    96.24  70.29]
# Array para la columna 'Rvir':
# [174.076 338.839 240.131 ... 109.661 158.159 138.164]
# Array para la columna 'Rs':
# [58.927 48.953 12.48  ... 10.801 29.512 53.274]
# Array para la columna 'Np':
# [ 32 119  26 ...  14  12  12]
# Array para la columna 'X':
# [184.08424 185.76231 186.53806 ... 397.50754 404.01361 297.46915]
# Array para la columna 'Y':
# [202.29651 203.21434 203.56975 ... 257.75354 392.50082 360.88617]
# Array para la columna 'Z':
# [ 83.96945  83.74827  84.30504 ... 369.15863 369.16299 369.14746]
# Array para la columna 'VX':
# [ 511.34  406.58   92.34 ... -236.93 -245.65 -388.64]
# Array para la columna 'VY':
# [ 944.22  614.9  1523.   ... -553.09  285.28  -22.42]
# Array para la columna 'VZ':
# [1072.37 1333.54  666.36 ...  362.36 -269.97 -377.65]
# Array para la columna 'JX':
# [ 1.297e+12 -1.519e+13  2.410e+12 ...  0.000e+00  3.164e+11 -1.076e+11]
# Array para la columna 'JY':
# [-1.585e+12 -3.930e+12  1.040e+12 ...  0.000e+00  4.226e+11 -4.201e+11]
# Array para la columna 'JZ':
# [ 7.814e+11  9.038e+11 -2.314e+12 ...  0.000e+00 -8.021e+11  1.058e+12]
# Array para la columna 'Spin':
# [0.04018 0.02726 0.03687 ... 0.      0.04668 0.03453]
# Array para la columna 'rs_klypin':
# [58.92749 48.95295 12.48044 ... 10.80068 29.512   53.27375]
# Array para la columna 'Mvir_all':
# [6.2021e+11 4.5740e+12 1.6280e+12 ... 1.5505e+11 4.6515e+11 3.1010e+11]
# Array para la columna 'M200b':
# [7.7526e+11 5.7369e+12 1.6280e+12 ... 2.3258e+11 4.6515e+11 3.8763e+11]
# Array para la columna 'M200c':
# [7.7526e+10 3.0235e+12 1.5505e+12 ... 1.5505e+11 3.1010e+11 7.7526e+10]
# Array para la columna 'M500b':
# [1.5505e+11 3.7988e+12 1.5505e+12 ... 1.5505e+11 4.6515e+11 7.7526e+10]
# Array para la columna 'M500c':
# [0.0000e+00 2.5583e+12 1.3179e+12 ... 0.0000e+00 1.5505e+11 0.0000e+00]
# Array para la columna 'Xoff':
# [90.91419 35.94954  6.11676 ... 63.96739 26.87901 39.67801]
# Array para la columna 'Voff':
# [20.22  0.    0.   ...  0.    0.   33.57]
# Array para la columna 'spin_bullock':
# [0.11597 0.02976 0.03707 ... 0.      0.08206 0.19205]
# Array para la columna 'b_to_a':
# [0.25353 0.42183 0.76075 ... 0.      0.28312 0.     ]
# Array para la columna 'c_to_a':
# [0.      0.29141 0.37867 ... 0.      0.0156  0.     ]
# Array para la columna 'A[x]':
# [-1.22805 49.75687 45.71273 ...  0.      -3.5715  21.97266]
# Array para la columna 'A[y]':
# [-32.6857  -35.04191  13.61973 ...   0.      -16.37277  11.90186]
# Array para la columna 'A[z]':
# [ 71.71382 -12.13828   2.04779 ...   0.       40.79342  53.19214]
# Array para la columna 'b_to_a(500b)':
# [0.      0.44362 0.74768 ... 0.      0.27638 0.     ]
# Array para la columna 'c_to_a(500b)':
# [0.      0.2823  0.35702 ... 0.      0.01534 0.     ]
# Array para la columna 'A[x](500b)':
# [ 0.      47.67883 46.17031 ...  0.      -3.80965  0.     ]
# Array para la columna 'A[y](500b)':
# [  0.      -30.40652  10.40742 ...   0.      -16.52045   0.     ]
# Array para la columna 'A[z](500b)':
# [ 0.      -9.83577  1.61027 ...  0.      41.34289  0.     ]
# Array para la columna 'T/|U|':
# [0.8473 0.5456 0.5651 ... 0.     0.6439 1.0775]
# Array para la columna 'M_pe_Behroozi':
# [8.445e+11 4.929e+12 2.806e+12 ... 4.876e+11 6.675e+11 4.780e+11]
# Array para la columna 'M_pe_Diemer':
# [7.753e+11 2.713e+12 3.876e+11 ... 0.000e+00 3.101e+11 5.427e+11]
# Array para la columna 'Halfmass_Radius':
# [145.09  148.819  72.221 ...  63.967  87.353 110.674]
# Error: El número de columnas en el DataFrame (41) no coincide con el número de encabezados (41).
# Tipo de datos para la columna 'ID': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'DescID': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Mvir': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Vmax': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Vrms': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Rvir': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Rs': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Np': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'X': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Y': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Z': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'VX': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'VY': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'VZ': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'JX': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'JY': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'JZ': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Spin': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'rs_klypin': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Mvir_all': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'M200b': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'M200c': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'M500b': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'M500c': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Xoff': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Voff': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'spin_bullock': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'b_to_a': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'c_to_a': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'A[x]': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'A[y]': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'A[z]': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'b_to_a(500b)': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'c_to_a(500b)': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'A[x](500b)': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'A[y](500b)': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'A[z](500b)': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'T/|U|': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'M_pe_Behroozi': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'M_pe_Diemer': <class 'numpy.ndarray'>
# Tipo de datos para la columna 'Halfmass_Radius': <class 'numpy.ndarray'>

# %%
for column, arr in numpy_arrays.items():
    print(f"La forma de los datos para la columna '{column}' es: {arr.shape}")
# Out:
# La forma de los datos para la columna 'ID' es: (817643,)
# La forma de los datos para la columna 'DescID' es: (817643,)
# La forma de los datos para la columna 'Mvir' es: (817643,)
# La forma de los datos para la columna 'Vmax' es: (817643,)
# La forma de los datos para la columna 'Vrms' es: (817643,)
# La forma de los datos para la columna 'Rvir' es: (817643,)
# La forma de los datos para la columna 'Rs' es: (817643,)
# La forma de los datos para la columna 'Np' es: (817643,)
# La forma de los datos para la columna 'X' es: (817643,)
# La forma de los datos para la columna 'Y' es: (817643,)
# La forma de los datos para la columna 'Z' es: (817643,)
# La forma de los datos para la columna 'VX' es: (817643,)
# La forma de los datos para la columna 'VY' es: (817643,)
# La forma de los datos para la columna 'VZ' es: (817643,)
# La forma de los datos para la columna 'JX' es: (817643,)
# La forma de los datos para la columna 'JY' es: (817643,)
# La forma de los datos para la columna 'JZ' es: (817643,)
# La forma de los datos para la columna 'Spin' es: (817643,)
# La forma de los datos para la columna 'rs_klypin' es: (817643,)
# La forma de los datos para la columna 'Mvir_all' es: (817643,)
# La forma de los datos para la columna 'M200b' es: (817643,)
# La forma de los datos para la columna 'M200c' es: (817643,)
# La forma de los datos para la columna 'M500b' es: (817643,)
# La forma de los datos para la columna 'M500c' es: (817643,)
# La forma de los datos para la columna 'Xoff' es: (817643,)
# La forma de los datos para la columna 'Voff' es: (817643,)
# La forma de los datos para la columna 'spin_bullock' es: (817643,)
# La forma de los datos para la columna 'b_to_a' es: (817643,)
# La forma de los datos para la columna 'c_to_a' es: (817643,)
# La forma de los datos para la columna 'A[x]' es: (817643,)
# La forma de los datos para la columna 'A[y]' es: (817643,)
# La forma de los datos para la columna 'A[z]' es: (817643,)
# La forma de los datos para la columna 'b_to_a(500b)' es: (817643,)
# La forma de los datos para la columna 'c_to_a(500b)' es: (817643,)
# La forma de los datos para la columna 'A[x](500b)' es: (817643,)
# La forma de los datos para la columna 'A[y](500b)' es: (817643,)
# La forma de los datos para la columna 'A[z](500b)' es: (817643,)
# La forma de los datos para la columna 'T/|U|' es: (817643,)
# La forma de los datos para la columna 'M_pe_Behroozi' es: (817643,)
# La forma de los datos para la columna 'M_pe_Diemer' es: (817643,)
# La forma de los datos para la columna 'Halfmass_Radius' es: (817643,)

# %%
pos_gas_X = np.array(df['X'])
pos_gas_Y = np.array(df['Y'])
pos_gas_Z = np.array(df['Z'])

# %%
print('%.2f < pos_gas_X < %.2f'%(np.min(df['X']), np.max(df['X'])))
print('%.2f < pos_gas_Y < %.2f'%(np.min(df['Y']), np.max(df['Y'])))
print('%.2f < pos_gas_Z < %.2f'%(np.min(df['Z']), np.max(df['Z'])))
# Out:
# 0.00 < pos_gas_X < 500.00
# 0.00 < pos_gas_Y < 500.00
# 0.00 < pos_gas_Z < 500.00

# %%
print('Number of star particles:', len(df['ID']))
# Out:
# Number of star particles: 817643

# %%
import numpy as np
import matplotlib.pyplot as plt

# Verifico el rango de los datos
print('Rango de X:', df['X'].min(), df['X'].max())
print('Rango de Y:', df['Y'].min(), df['Y'].max())

# Ajusto los límites de los ejes
plt.xlim(df['X'].min(), df['X'].max())
plt.ylim(df['Y'].min(), df['Y'].max())

aux_ind = np.random.choice(np.arange(len(df)), size=1000, replace=False)
plt.scatter(df.iloc[aux_ind]['X'], df.iloc[aux_ind]['Y'], color='green', marker='+', s=10, label='gas')


#Leyenda y etiquetas
plt.legend(loc='upper left')
plt.xlabel(r'$X_{*}$')
plt.ylabel(r'$Y_{*}$')

plt.show()
# Out:
# Rango de X: 0.00015 499.99997
# Rango de Y: 0.00063 499.99948

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

n_points = 1000  

# Generar índices aleatorios sin reemplazo para tomar solo una parte de los datos
aux_ind = np.random.choice(np.arange(len(df)), size=n_points, replace=False)

# Gráfico de dispersión 3D usando los puntos seleccionados aleatoriamente
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(df.iloc[aux_ind]['X'], df.iloc[aux_ind]['Y'], df.iloc[aux_ind]['Z'], c=df.iloc[aux_ind]['VY'], cmap='viridis')

#Barra de colores
fig.colorbar(scatter)

#Etiquetas y título
plt.xlabel(r'$X_{*}$')
plt.ylabel(r'$Y_{*}$')
ax.set_zlabel(r'$Z_{*}$')
plt.title('Gráfico 3D de dispersión')

plt.show()

# %%
# Now, lets read the positions, velocities, masses, and lenghts of the halos
pos_hx     = df['X']    #Mpc/h
pos_hy     = df['Y']    #Mpc/h
pos_hz     = df['Z']    #Mpc/h
vel_hx     = df['VX']   #km/s
vel_hy     = df['VY']   #km/s
vel_hz     = df['VZ']   #km/s
mass_h     = df['Mvir'] #Msun/h

# %%
pos_hx.shape
# Out:
# (817643,)

# %%
# Lets print the position, velocity, mass and length of a given halo
index = 167 #index of the halo
print('position:',pos_hx[index],'Mpc/h')
print('velocity:',vel_hx[index],'km/s')
print('mass: %.3e Msun/h'%mass_h[index])
# Out:
# position: 85.89774 Mpc/h
# velocity: -187.65 km/s
# mass: 6.977e+11 Msun/h

# %%
f = h5py.File(r'/home/acastello/halos_list_con_headers.h5', 'r')

pos_hx     = df['X']    #Mpc/h
pos_hy     = df['Y']    #Mpc/h
pos_hz     = df['Z']    #Mpc/h
vel_hx     = df['VX']   #km/s
vel_hy     = df['VY']   #km/s
vel_hz     = df['VZ']   #km/s
mass_h     = df['Mvir'] #Msun/h

pos_h = np.stack([pos_hx, pos_hy, pos_hz], axis=1)
vel_h = np.stack([vel_hx, vel_hy, vel_hz], axis=1)

# Para la constante gravitacional G en unidades apropiadas, km^2 Mpc / (Msun s^2))
G = -6.67430e-11  # m^3 / (kg s^2)
G_km2_Mpc = G * (1e-3)**2 * (3.0857e22) / (1.98847e30)  # convierte a km^2 Mpc / (Msun s^2)
 

for i in range(pos_h.shape[0]):
    x0, y0, z0 = pos_h[i]
    vx0, vy0, vz0 = vel_h[i]
    m = mass_h[i]
    # Llamo a la función que quiera con esos valores

def potencial(x,y,z):

    dx = x - pos_h[:, 0] 
    dy = y - pos_h[:, 1] 
    dz = z - pos_h[:, 2] 

    r = np.sqrt(dx**2 + dy**2 + dz**2)  # para evitar división por cero   

    phi = G_km2_Mpc * np.sum(mass_h / r) #tiene unidades de km**3 * h / (s**2 * Mph)

    return phi

def potenciali(x, y, z, i):
    
    dx_i = x - pos_h[i, 0]
    dy_i = y - pos_h[i, 1]
    dz_i = z - pos_h[i, 2]
    
    r_i = np.sqrt(dx_i**2 + dy_i**2 + dz_i**2) + 1e-3
     
    phi_i = G_km2_Mpc * mass_h[i] / r_i
    
    return phi_i

def potencialpunto(x,y,z):

    dx = x - pos_h[:, 0] 
    dy = y - pos_h[:, 1] 
    dz = z - pos_h[:, 2] 

    vr = vel_h[:, 0]*dx + vel_h[:, 1]*dy + vel_h[:, 2]*dz
    r = np.sqrt(dx**2 + dy**2 + dz**2)  # para evitar división por cero   
    
    phipunto = G_km2_Mpc * np.sum(mass_h * vr / r**(1.5)) #tiene unidades de km**3 * h / (s**3 * Mph)

    return phipunto

def potencialpuntoi(x, y, z, i):
    
    dx_i = x - pos_h[i, 0]
    dy_i = y - pos_h[i, 1]
    dz_i = z - pos_h[i, 2]
    
    r_i = np.sqrt(dx_i**2 + dy_i**2 + dz_i**2) 
    vr_i = vel_h[i, 0]*dx_i + vel_h[i, 1]*dy_i + vel_h[i, 2]*dz_i
    
    phipunto_i = G_km2_Mpc * mass_h[i] * vr_i / r_i**1.5
    
    return phipunto_i

# Para comparar:
x, y, z = 0, 0, 0
phipunto_i = potencialpuntoi(x, y, z, i=0)
phipunto_total = potencialpunto(x, y, z)
phiprint = potencial(x,y,z)
phi_i = potenciali(x,y,z, i=0)

print("Primer término individual:", phipunto_i)
print("Suma total:", phipunto_total)
print("potencial:", phiprint)
print("Primer término potencial:", phi_i)
# Out:
# Primer término individual: 4.979866764007392e-11
# Suma total: -2.1142441980054499e-07
# potencial: -7.95150287285364e-09
# Primer término potencial: -2.245107314445449e-15

# %%
print(pos_h[0])
print(mass_h[0])
# Out:
# [184.08424 202.29651  83.96945]
# 620210000000.0

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import colors

# creo un conjunto de valores en cada eje:
valores = np.linspace(np.min(pos_h), np.max(pos_h), 15)  

# creo una malla 3D
X, Y, Z = np.meshgrid(valores, valores, valores)

# creo un array vacío para los resultados
Phipunto = np.zeros(X.shape)

# evalúo la función en cada punto
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        for k in range(X.shape[2]):
            x_val = X[i, j, k]
            y_val = Y[i, j, k]
            z_val = Z[i, j, k]
            Phipunto[i, j, k] = potencialpunto(x_val, y_val, z_val)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

#elijo un subconjunto para no graficar millones de puntos, si pongo 
#skip = (slice(None, None, 2), slice(None, None, 2), slice(None, None, 2)), 
#tarda mucho menos pero hay menos puntos graficados

skip = (slice(None), slice(None), slice(None))

X_sub = X[skip]
Y_sub = Y[skip]
Z_sub = Z[skip]
Phipunto_sub = Phipunto[skip]

# convierto a vectores para scatter
norm = colors.Normalize(vmin=np.min(Phipunto_sub), vmax=np.max(Phipunto_sub))
ax.scatter(X_sub.flatten(), Y_sub.flatten(), Z_sub.flatten(),
           c=Phipunto_sub.flatten(), cmap='plasma', norm=norm, s=3)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Distribución del potencial punto')
plt.show()
# Out:
# KeyboardInterrupt

# %%
import numpy as np
import matplotlib.pyplot as plt

# creo un conjunto de valores en cada eje
valores = np.linspace(np.min(pos_h), np.max(pos_h), 15)

# malla tridimensional
X, Y, Z = np.meshgrid(valores, valores, valores)

# array para los resultados
Phipunto = np.zeros(X.shape)

# evalúo la función en cada punto
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        for k in range(X.shape[2]):
            x_val = X[i, j, k]
            y_val = Y[i, j, k]
            z_val = Z[i, j, k]
            Phipunto[i, j, k] = potencialpunto(x_val, y_val, z_val)

# promedio en el eje Z (axis=2 al usar np.meshgrid con default indexing)
Phipunto_promedio_z = np.mean(Phipunto, axis=2)

# Calculo el rango solo sobre los datos que efectivamente aparecen
vmin = np.min(Phipunto_promedio_z)
vmax = np.max(Phipunto_promedio_z)

# genero el gráfico 2D (mapa de calor)
plt.figure(figsize=(8, 6))
plt.imshow(Phipunto_promedio_z, origin='lower', cmap='plasma',
           extent=(valores.min(), valores.max(), valores.min(), valores.max()),
           aspect='auto', vmin=vmin, vmax=vmax)
plt.colorbar(label='Potencial punto promedio')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Promedio del potencial punto en Z')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Malla 3D
valores = np.linspace(np.min(pos_h), np.max(pos_h), 15)
X, Y, Z = np.meshgrid(valores, valores, valores)
Phipunto = np.zeros(X.shape)

# Evaluación del potencial punto
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        for k in range(X.shape[2]):
            x_val = X[i, j, k]
            y_val = Y[i, j, k]
            z_val = Z[i, j, k]
            Phipunto[i, j, k] = potencialpunto(x_val, y_val, z_val)

# Promedio sobre Z
Phipunto_promedio_z = np.mean(Phipunto, axis=2)

# Verificamos que los datos son válidos
if np.all(np.isnan(Phipunto_promedio_z)) or np.max(Phipunto_promedio_z) == np.min(Phipunto_promedio_z):
    print("Advertencia: los datos del potencial están vacíos o son constantes.")

# %%
plt.figure(figsize=(8, 6))

img = plt.imshow(Phipunto_promedio_z.T, origin='lower', cmap='plasma',
                 extent=[valores.min(), valores.max(), valores.min(), valores.max()],
                 aspect='equal')

x_pos = pos_h[:, 0]
y_pos = pos_h[:, 1]

# Máscara para mantener solo los puntos dentro del rango de la imagen
mask = (x_pos >= valores.min()) & (x_pos <= valores.max()) & \
       (y_pos >= valores.min()) & (y_pos <= valores.max())

print("Puntos dentro del rango:", np.sum(mask))  # Verificación

# Aplicar la máscara
x_filtrado = x_pos[mask]
y_filtrado = y_pos[mask]

# Mostrar solo una cantidad fija de puntos, para 0.025 siguen siendo muchos
fraccion = 0.015
cantidad = int(len(x_filtrado) * fraccion)


if cantidad > 0:
    indices = np.random.choice(len(x_filtrado), cantidad, replace=False)
    plt.scatter(x_filtrado[indices], y_filtrado[indices], color='white', s=5, alpha=0.5)

plt.colorbar(img, label='Potencial punto promedio en Z')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Mapa 2D del potencial punto promedio en Z')
plt.tight_layout()
plt.show()
# Out:
# Puntos dentro del rango: 817643

# %%
import numpy as np
import matplotlib.pyplot as plt

# elijo una partícula al azar 
i = np.random.randint(len(pos_h))

# creo grilla de puntos
valores = np.linspace(np.min(pos_h), np.max(pos_h), 10)
X, Y, Z = np.meshgrid(valores, valores, valores)

# inicio el array para resultados
Phipunto_i = np.zeros(X.shape)

# evalúo el potencial punto solo para la partícula i en toda la grilla
for ix in range(X.shape[0]):
    for iy in range(X.shape[1]):
        for iz in range(X.shape[2]):
            x_val = X[ix, iy, iz]
            y_val = Y[ix, iy, iz]
            z_val = Z[ix, iy, iz]
            Phipunto_i[ix, iy, iz] = potencialpuntoi(x_val, y_val, z_val, i)

# promedio sobre Z
Phipunto_i_mean_z = np.mean(Phipunto_i, axis=2)

# calculo vmin y vmax para que la colorbar sirva
vmin = np.percentile(Phipunto_i_mean_z, 2)
vmax = np.percentile(Phipunto_i_mean_z, 98)

plt.figure(figsize=(8, 6))
im = plt.imshow(Phipunto_i_mean_z, origin='lower', cmap='plasma',
                extent=(valores.min(), valores.max(), valores.min(), valores.max()),
                aspect='auto', vmin=vmin, vmax=vmax)

# por si quiero superponer todas las posiciones de halos (proyectadas en XY):
#x_pos = pos_h[:, 0]
#y_pos = pos_h[:, 1]
#plt.scatter(x_pos, y_pos, color='white', s=1, alpha=0.3, label='Posiciones de halos')

# marco la posición de la partícula i
plt.scatter(pos_h[i, 0], pos_h[i, 1], color='red', s=20, label=f'Halo {i}', zorder=3)

plt.colorbar(im, label=f'Potencial punto generado por halo {i} (prom. en Z)')
plt.xlabel('X (Mpc/h)')
plt.ylabel('Y (Mpc/h)')
plt.title(f'Potencial punto individual generado por halo {i}')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import colors

# creo un conjunto de valores en cada eje:
valores = np.linspace(np.min(pos_h), np.max(pos_h), 10)  

# creo una malla 3D
X, Y, Z = np.meshgrid(valores, valores, valores)

# creo un array vacío para los resultados
Phi = np.zeros(X.shape)

# evalúo la función en cada punto
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        for k in range(X.shape[2]):
            x_val = X[i, j, k]
            y_val = Y[i, j, k]
            z_val = Z[i, j, k]
            Phi[i, j, k] = potencial(x_val, y_val, z_val)

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

#elijo un subconjunto para no graficar millones de puntos, si pongo 
#skip = (slice(None, None, 2), slice(None, None, 2), slice(None, None, 2)), 
#tarda mucho menos pero hay menos puntos graficados

skip = (slice(None), slice(None), slice(None))

X_sub = X[skip]
Y_sub = Y[skip]
Z_sub = Z[skip]
Phi_sub = Phi[skip]

# convierto a vectores para scatter
norm = colors.Normalize(vmin=np.min(Phi_sub), vmax=np.max(Phi_sub))
ax.scatter(X_sub.flatten(), Y_sub.flatten(), Z_sub.flatten(),
           c=Phi_sub.flatten(), cmap='plasma', norm=norm, s=3)

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Distribución del potencial')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# creo los valores para la grilla
valores = np.linspace(np.min(pos_h), np.max(pos_h), 10)

# creo la malla 3D
X, Y, Z = np.meshgrid(valores, valores, valores)

# array vacío para los resultados
Phi = np.zeros(X.shape)

# evalúo potencial en toda la grilla
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        for k in range(X.shape[2]):
            x_val = X[i, j, k]
            y_val = Y[i, j, k]
            z_val = Z[i, j, k]
            Phi[i, j, k] = potencial(x_val, y_val, z_val)

# promedio en el eje Z (axis=2 si se usa np.meshgrid con default indexing)
Phi_promedio_z = np.mean(Phi, axis=2)

# generar el gráfico 2D (mapa de calor)
plt.figure(figsize=(8, 6))
plt.imshow(Phi_promedio_z, origin='lower', cmap='plasma',
           extent=(valores.min(), valores.max(), valores.min(), valores.max()),
           aspect='auto')
plt.colorbar(label='Potencial promedio')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Promedio del potencial en Z')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# creo los valores para la grilla
valores = np.linspace(np.min(pos_h), np.max(pos_h), 10)

# creo la malla 3D
X, Y, Z = np.meshgrid(valores, valores, valores)

Phi = np.zeros(X.shape)

# evalúo potencial en toda la grilla
for i in range(X.shape[0]):
    for j in range(X.shape[1]):
        for k in range(X.shape[2]):
            x_val = X[i, j, k]
            y_val = Y[i, j, k]
            z_val = Z[i, j, k]
            Phi[i, j, k] = potencial(x_val, y_val, z_val)

# promedio en el eje Z (axis=2 al usar np.meshgrid con default indexing)
Phi_promedio_z = np.mean(Phi, axis=2)

# grafico el mapa de calor
vmin = np.min(Phi_promedio_z)
vmax = np.max(Phi_promedio_z)

# %%
plt.figure(figsize=(8, 6))
im = plt.imshow(Phi_promedio_z, origin='lower', cmap='plasma',
                extent=(valores.min(), valores.max(), valores.min(), valores.max()),
                aspect='auto', vmin=vmin, vmax=vmax)

# Posiciones proyectadas en XY
x_pos = pos_h[:, 0]
y_pos = pos_h[:, 1]

# Filtro: posiciones dentro del rango de valores
mask = (x_pos >= valores.min()) & (x_pos <= valores.max()) & \
       (y_pos >= valores.min()) & (y_pos <= valores.max())

# Filtro
x_filtrado = x_pos[mask]
y_filtrado = y_pos[mask]

# Tomo una fraccion de puntos
fraccion = 0.025  # Cambiando este valor consigo graficar menos puntos, para 0.05 sigue viendose raro
cantidad = int(len(x_filtrado) * fraccion)

if cantidad > 0:
    indices = np.random.choice(len(x_filtrado), cantidad, replace=False)
    plt.scatter(x_filtrado[indices], y_filtrado[indices], s=5, alpha=0.5, label='Posiciones')

plt.colorbar(im, label='Potencial promedio')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Promedio del potencial en Z + posiciones')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# elijo una partícula al azar 
i = 1

# creo grilla de puntos
valores = np.linspace(np.min(pos_h), np.max(pos_h), 50)
X, Y, Z = np.meshgrid(valores, valores, valores)

# inicio el array para resultados
Phi_i = np.zeros(X.shape)

# evalúo el potencial solo para la partícula i en toda la grilla
for ix in range(X.shape[0]):
    for iy in range(X.shape[1]):
        for iz in range(X.shape[2]):
            x_val = X[ix, iy, iz]
            y_val = Y[ix, iy, iz]
            z_val = Z[ix, iy, iz]
            Phi_i[ix, iy, iz] = potenciali(x_val, y_val, z_val, i)

# promedio en el eje Z (axis=2 al usar np.meshgrid con default indexing)
Phi_i_mean_z = np.mean(Phi_i, axis=2)

# calculo vmin y vmax para que la colorbar sirva
vmin = np.percentile(Phi_i_mean_z, 2)
vmax = np.percentile(Phi_i_mean_z, 98)

plt.figure(figsize=(8, 6))
im = plt.imshow(Phi_i_mean_z, origin='lower', cmap='plasma',
                extent=(valores.min(), valores.max(), valores.min(), valores.max()),
                aspect='auto', vmin=vmin, vmax=vmax)

# por si quiero superponer todas las posiciones de halos (proyectadas en XY):
#x_pos = pos_h[:, 0]
#y_pos = pos_h[:, 1]
#plt.scatter(x_pos, y_pos, color='white', s=1, alpha=0.3, label='Posiciones de halos')

# marco la posición de la partícula i
plt.scatter(pos_h[i, 0], pos_h[i, 1], color='red', s=20, label=f'Halo {i}', zorder=3)

plt.colorbar(im, label=f'Potencial generado por halo {i} (prom. en Z)')
plt.xlabel('X (Mpc/h)')
plt.ylabel('Y (Mpc/h)')
plt.title(f'Potencial individual generado por halo {i}')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Convertir a logaritmo base 10
log_mass_h = np.log10(mass_h[mass_h > 0])  # filtramos para evitar log(0)

# Histograma en escala logarítmica
plt.figure(figsize=(8, 6))
plt.hist(log_mass_h, bins=75, edgecolor='black')

plt.xlabel('log10(Masa)')
plt.ylabel('Frecuencia')
plt.title('Distribución logarítmica de masas')

plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Stack de posiciones (X, Y, Z)
pos_h = np.stack([pos_hx, pos_hy, pos_hz], axis=1)

x = pos_h[:, 0]
y = pos_h[:, 1]
z = pos_h[:, 2]

# Parámetros del grid
nbins = 100  #ajustar la resolución
x_range = (np.min(x), np.max(x))
y_range = (np.min(y), np.max(y))

# Histograma 2D de suma de masas en XY
mass_map, xedges, yedges = np.histogram2d(
    x, y, bins=nbins, range=[x_range, y_range], weights=mass_h
)

#calcular la cantidad de puntos por bin (para promedio)
count_map, _, _ = np.histogram2d(
    x, y, bins=nbins, range=[x_range, y_range]
)

# mapa de densidad promedio en Z
average_mass_map = np.divide(mass_map, count_map, out=np.zeros_like(mass_map), where=count_map!=0)

#suma de masas por pixel
plt.figure(figsize=(8, 6))
plt.imshow(
    mass_map.T, origin='lower',
    extent=[x_range[0], x_range[1], y_range[0], y_range[1]],
    aspect='auto'
)
plt.colorbar(label='Masa total')
plt.xlabel('X [Mpc/h]')
plt.ylabel('Y [Mpc/h]')
plt.title('Mapa de densidad de masa (integrado en Z)')
plt.tight_layout()
plt.show()

# %%
dx = (x_range[1] - x_range[0]) / nbins
dy = (y_range[1] - y_range[0]) / nbins
bin_area = dx * dy

density_map = mass_map / (dx * dy)

plt.figure(figsize=(8, 6))
plt.imshow(
    density_map.T, origin='lower',
    extent=[x_range[0], x_range[1], y_range[0], y_range[1]],
    aspect='auto'
)
plt.colorbar(label='Densidad superficial de masa [M⊙ / (Mpc/h)²]')
plt.xlabel('X [Mpc/h]')
plt.ylabel('Y [Mpc/h]')
plt.title('Mapa de densidad superficial (proyectado en Z)')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetros
nbins = 50  
ranges = [
    (np.min(pos_h[:, 0]), np.max(pos_h[:, 0])),  # X
    (np.min(pos_h[:, 1]), np.max(pos_h[:, 1])),  # Y
    (np.min(pos_h[:, 2]), np.max(pos_h[:, 2])),  # Z
]

# Histograma 3D suma de masas en cada celda
mass_grid, edges = np.histogramdd(pos_h, bins=nbins, range=ranges, weights=mass_h)

# Calcular tamaño de celda en cada dimensión
dx = (ranges[0][1] - ranges[0][0]) / nbins
dy = (ranges[1][1] - ranges[1][0]) / nbins
dz = (ranges[2][1] - ranges[2][0]) / nbins
cell_volume = dx * dy * dz  # en (Mpc/h)^3

# Densidad volumétrica
density_grid = mass_grid / cell_volume  # [M⊙ / (Mpc/h)^3]

# %%
z_index = 2

plt.figure(figsize=(8, 6))
plt.imshow(
    density_grid[:, :, z_index].T,  # transponer para que el eje Y esté bien
    origin='lower',
    extent=[ranges[0][0], ranges[0][1], ranges[1][0], ranges[1][1]],
    aspect='auto'
)
plt.colorbar(label='Densidad [M⊙ / (Mpc/h)^3]')
plt.xlabel('X [Mpc/h]')
plt.ylabel('Y [Mpc/h]')
plt.title(f'Densidad volumétrica en Z = slice {z_index}')
plt.tight_layout()
plt.show()

# %%
average_density_xy = np.mean(density_grid, axis=2)

avg = np.mean(density_grid, axis=2)

dz = (ranges[2][1] - ranges[2][0]) / nbins
integrated = np.sum(density_grid, axis=2) * dz  # M⊙ / (Mpc/h)^2

plt.figure(figsize=(8, 6))
plt.imshow(
    average_density_xy.T, origin='lower',
    extent=[ranges[0][0], ranges[0][1], ranges[1][0], ranges[1][1]],
    aspect='auto'
)
plt.colorbar(label='Densidad promedio [M⊙ / (Mpc/h)^3]')
plt.xlabel('X [Mpc/h]')
plt.ylabel('Y [Mpc/h]')
plt.title('Densidad promedio proyectada sobre Z (mapa XY)')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = pos_h[:, 0]
y = pos_h[:, 1]

# Módulo de velocidad
vel_magnitude = np.linalg.norm(vel_h, axis=1)

# Parámetros 
nbins = 100
x_range = (np.min(x), np.max(x))
y_range = (np.min(y), np.max(y))

# Histograma 2D suma de |v| por celda
vel_sum_map, xedges, yedges = np.histogram2d(
    x, y, bins=nbins, range=[x_range, y_range], weights=vel_magnitude
)

# Histograma 2D cuenta de partículas por celda
count_map, _, _ = np.histogram2d(
    x, y, bins=nbins, range=[x_range, y_range]
)

# Promedio: |v| promedio en cada celda
average_velocity_map = np.divide(
    vel_sum_map, count_map,
    out=np.zeros_like(vel_sum_map), where=count_map != 0
)

# %%
plt.figure(figsize=(8, 6))
plt.imshow(
    average_velocity_map.T, origin='lower',
    extent=[x_range[0], x_range[1], y_range[0], y_range[1]],
    aspect='auto'
)
plt.colorbar(label='Velocidad promedio [km/s]')
plt.xlabel('X [Mpc/h]')
plt.ylabel('Y [Mpc/h]')
plt.title('Mapa XY de velocidad promedio (proyectado en Z)')
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

nbins = 50

#módulo de velocidad
vel_magnitude = np.linalg.norm(vel_h, axis=1)

# Rango del volumen
ranges = [
    (np.min(pos_h[:, 0]), np.max(pos_h[:, 0])),  # X
    (np.min(pos_h[:, 1]), np.max(pos_h[:, 1])),  # Y
    (np.min(pos_h[:, 2]), np.max(pos_h[:, 2])),  # Z
]

# Histograma 3D de suma de velocidades
vel_sum_grid, edges = np.histogramdd(
    pos_h, bins=nbins, range=ranges, weights=vel_magnitude
)

# Histograma 3D de conteo de partículas
count_grid, _ = np.histogramdd(
    pos_h, bins=nbins, range=ranges
)

# Promedio de velocidades por celda
average_vel_grid = np.divide(
    vel_sum_grid, count_grid,
    out=np.zeros_like(vel_sum_grid), where=count_grid != 0
)

# %%
z_index = 25  # cualquier valor entre 0 y nbins - 1

plt.figure(figsize=(8, 6))
plt.imshow(
    average_vel_grid[:, :, z_index].T, origin='lower',
    extent=[ranges[0][0], ranges[0][1], ranges[1][0], ranges[1][1]],
    aspect='auto'
)
plt.colorbar(label='Velocidad promedio [km/s]')
plt.xlabel('X [Mpc/h]')
plt.ylabel('Y [Mpc/h]')
plt.title(f'Mapa XY de velocidad promedio (slice Z={z_index})')
plt.tight_layout()
plt.show()

# %%
from ipywidgets import interact

def plot_slice(z_index):
    plt.figure(figsize=(8, 6))
    plt.imshow(
        average_vel_grid[:, :, z_index].T, origin='lower',
        extent=[ranges[0][0], ranges[0][1], ranges[1][0], ranges[1][1]],
        aspect='auto'
    )
    plt.colorbar(label='Velocidad promedio [km/s]')
    plt.xlabel('X [Mpc/h]')
    plt.ylabel('Y [Mpc/h]')
    plt.title(f'Slice Z = {z_index}')
    plt.tight_layout()
    plt.show()

interact(plot_slice, z_index=(0, nbins - 1))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 from ipywidgets import interact
#       3 def plot_slice(z_index):
#       4     plt.figure(figsize=(8, 6))
#
# ModuleNotFoundError: No module named 'ipywidgets'

# %%
import numpy as np
import matplotlib.pyplot as plt

# módulo de velocidad para todas las partículas
vel_magnitude = np.linalg.norm(vel_h, axis=1)

# mapa 2D promedio en Z
x_all = pos_h[:, 0]
y_all = pos_h[:, 1]

nbins = 100
x_range = (np.min(x_all), np.max(x_all))
y_range = (np.min(y_all), np.max(y_all))

# Suma de velocidades en cada celda
vel_sum_map, _, _ = np.histogram2d(
    x_all, y_all, bins=nbins, range=[x_range, y_range], weights=vel_magnitude
)

# Conteo de partículas por celda
count_map, _, _ = np.histogram2d(
    x_all, y_all, bins=nbins, range=[x_range, y_range]
)

# Velocidad promedio por celda
average_vel_map = np.divide(
    vel_sum_map, count_map, out=np.zeros_like(vel_sum_map), where=count_map != 0
)

# seleccionar las 1000 partículas más masivas 
indices_top = np.argsort(mass_h)[-1000:]
pos_top = pos_h[indices_top]
vel_top = vel_h[indices_top]

x_top = pos_top[:, 0]
y_top = pos_top[:, 1]
vx_top = vel_top[:, 0]
vy_top = vel_top[:, 1]

plt.figure(figsize=(10, 8))

# Mapa de fondo (velocidad promedio proyectada en Z)
plt.imshow(
    average_vel_map.T,
    origin='lower',
    extent=[x_range[0], x_range[1], y_range[0], y_range[1]],
    aspect='auto',
    cmap='viridis'
)
plt.colorbar(label='Velocidad promedio [km/s]')

# Flechas de las 1000 partículas más masivas
plt.quiver(x_top, y_top, vx_top, vy_top, angles='xy', scale_units='xy', scale=85, color='black', alpha=1)

plt.xlabel('X [Mpc/h]')
plt.ylabel('Y [Mpc/h]')
plt.title('Mapa XY de velocidad promedio (proyectado en Z) con vectores de las 1000 partículas más masivas')
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interact

# Parámetros
nbins = 50  # número de bins por eje
x_range = (np.min(pos_h[:,0]), np.max(pos_h[:,0]))
y_range = (np.min(pos_h[:,1]), np.max(pos_h[:,1]))
z_range = (np.min(pos_h[:,2]), np.max(pos_h[:,2]))
dz = (z_range[1] - z_range[0]) / nbins

# 1000 más masivas
indices_top = np.argsort(mass_h)[-1000:]
pos_top = pos_h[indices_top]
vel_top = vel_h[indices_top]

def plot_slice(z_index):
    # Limites del slice
    z_min = z_range[0] + z_index*dz
    z_max = z_min + dz
    
    # Filtrar partículas en el slice 
    mask_slice = (pos_h[:,2] >= z_min) & (pos_h[:,2] < z_max)
    x_slice = pos_h[mask_slice, 0]
    y_slice = pos_h[mask_slice, 1]
    vel_slice = np.linalg.norm(vel_h[mask_slice], axis=1)
    
    # Histograma 2D del módulo de velocidad promedio en XY dentro del slice
    vel_sum_map, _, _ = np.histogram2d(
        x_slice, y_slice, bins=nbins, range=[x_range, y_range], weights=vel_slice
    )
    count_map, _, _ = np.histogram2d(
        x_slice, y_slice, bins=nbins, range=[x_range, y_range]
    )
    average_vel_map = np.divide(vel_sum_map, count_map, out=np.zeros_like(vel_sum_map), where=count_map!=0)
    
    # Filtrar partículas top dentro del slice
    mask_top_slice = (pos_top[:,2] >= z_min) & (pos_top[:,2] < z_max)
    x_top_slice = pos_top[mask_top_slice, 0]
    y_top_slice = pos_top[mask_top_slice, 1]
    vx_top_slice = vel_top[mask_top_slice, 0]
    vy_top_slice = vel_top[mask_top_slice, 1]
    
    plt.figure(figsize=(10, 8))
    plt.imshow(
        average_vel_map.T,
        origin='lower',
        extent=[x_range[0], x_range[1], y_range[0], y_range[1]],
        aspect='auto',
        cmap='viridis'
    )
    plt.colorbar(label='Velocidad promedio [km/s]')
    
    # Flechas de partículas top
    if len(x_top_slice) > 0:
        plt.quiver(x_top, y_top, vx_top, vy_top, angles='xy', scale_units='xy', scale=85, color='black', alpha=1)
    
    plt.xlabel('X [Mpc/h]')
    plt.ylabel('Y [Mpc/h]')
    plt.title(f'Slice Z {z_index} (altura {z_min:.2f} - {z_max:.2f})')
    plt.tight_layout()
    plt.show()

# Slider interactivo
interact(plot_slice, z_index=(0, nbins-1));
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[36], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from ipywidgets import interact
#       5 # Parámetros
#       6 nbins = 50  # número de bins por eje
#
# ModuleNotFoundError: No module named 'ipywidgets'
